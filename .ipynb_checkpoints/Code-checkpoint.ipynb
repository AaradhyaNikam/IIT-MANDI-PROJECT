# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_excel("Bengaluru_House_Data.xlsx")

# %%
df
# Out:
#                   area_type         availability                  location  \
# 0      Super built-up  Area  2025-12-19 00:00:00  Electronic City Phase II
# 1                Plot  Area        Ready To Move          Chikka Tirupathi
# 2            Built-up  Area        Ready To Move               Uttarahalli
# 3      Super built-up  Area        Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area        Ready To Move                  Kothanur
# ...                     ...                  ...                       ...
# 13315        Built-up  Area        Ready To Move                Whitefield
# 13316  Super built-up  Area        Ready To Move             Richards Town
# 13317        Built-up  Area        Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area  2025-06-18 00:00:00           Padmanabhanagar
# 13319  Super built-up  Area        Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# ...

# %%
df.isnull().sum().sum()
# Out:
# 6201

# %%
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df.head()
# Out:
#               area_type         availability                  location  \
# 0  Super built-up  Area  2025-12-19 00:00:00  Electronic City Phase II
# 1            Plot  Area        Ready To Move          Chikka Tirupathi
# 2        Built-up  Area        Ready To Move               Uttarahalli
# 3  Super built-up  Area        Ready To Move        Lingadheeranahalli
# 4  Super built-up  Area        Ready To Move                  Kothanur
#
#         size  society total_sqft  bath  balcony   price
# 0      2 BHK  Coomee        1056   2.0      1.0   39.07
# 1  4 Bedroom  Theanmp       2600   5.0      3.0  120.00
# 2      3 BHK      NaN       1440   2.0      3.0   62.00
# 3      3 BHK  Soiewre       1521   3.0      1.0   95.00
# 4      2 BHK      NaN       1200   2.0      1.0   51.00

# %%
df.iloc[1]
# Out:
# area_type             Plot  Area
# availability       Ready To Move
# location        Chikka Tirupathi
# size                   4 Bedroom
# society                  Theanmp
# total_sqft                  2600
# bath                         5.0
# balcony                      3.0
# price                      120.0
# Name: 1, dtype: object

# %%
df2 = df.fillna(value=0)

# %%
df2.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# society         0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %%
df2.isnull().sum().sum()
# Out:
# 0

# %%
df
# Out:
#                   area_type         availability                  location  \
# 0      Super built-up  Area  2025-12-19 00:00:00  Electronic City Phase II
# 1                Plot  Area        Ready To Move          Chikka Tirupathi
# 2            Built-up  Area        Ready To Move               Uttarahalli
# 3      Super built-up  Area        Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area        Ready To Move                  Kothanur
# ...                     ...                  ...                       ...
# 13315        Built-up  Area        Ready To Move                Whitefield
# 13316  Super built-up  Area        Ready To Move             Richards Town
# 13317        Built-up  Area        Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area  2025-06-18 00:00:00           Padmanabhanagar
# 13319  Super built-up  Area        Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# ...

# %%
df3 = df.ffill()

# %%
df3.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# society         0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %%
# Filling nulll values with next values
df4 = df.bfill()

# %%
df4
# Out:
#                   area_type         availability                  location  \
# 0      Super built-up  Area  2025-12-19 00:00:00  Electronic City Phase II
# 1                Plot  Area        Ready To Move          Chikka Tirupathi
# 2            Built-up  Area        Ready To Move               Uttarahalli
# 3      Super built-up  Area        Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area        Ready To Move                  Kothanur
# ...                     ...                  ...                       ...
# 13315        Built-up  Area        Ready To Move                Whitefield
# 13316  Super built-up  Area        Ready To Move             Richards Town
# 13317        Built-up  Area        Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area  2025-06-18 00:00:00           Padmanabhanagar
# 13319  Super built-up  Area        Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# ...

# %%
df4.isnull().sum().sum()
# Out:
# 1

# %%
df5 = df.fillna(method="pad",axis=1)
# Out:
# C:\Users\AARADHYA\AppData\Local\Temp\ipykernel_4140\1600502410.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df5 = df.fillna(method="pad",axis=1)

# %%
df5
# Out:
#                   area_type         availability                  location  \
# 0      Super built-up  Area  2025-12-19 00:00:00  Electronic City Phase II
# 1                Plot  Area        Ready To Move          Chikka Tirupathi
# 2            Built-up  Area        Ready To Move               Uttarahalli
# 3      Super built-up  Area        Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area        Ready To Move                  Kothanur
# ...                     ...                  ...                       ...
# 13315        Built-up  Area        Ready To Move                Whitefield
# 13316  Super built-up  Area        Ready To Move             Richards Town
# 13317        Built-up  Area        Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area  2025-06-18 00:00:00           Padmanabhanagar
# 13319  Super built-up  Area        Ready To Move              Doddathoguru
#
#             size  society total_sqft bath balcony  price
# ...

# %%
df6 = df.ffill(axis=1)

# %%
df6
# Out:
#                   area_type         availability                  location  \
# 0      Super built-up  Area  2025-12-19 00:00:00  Electronic City Phase II
# 1                Plot  Area        Ready To Move          Chikka Tirupathi
# 2            Built-up  Area        Ready To Move               Uttarahalli
# 3      Super built-up  Area        Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area        Ready To Move                  Kothanur
# ...                     ...                  ...                       ...
# 13315        Built-up  Area        Ready To Move                Whitefield
# 13316  Super built-up  Area        Ready To Move             Richards Town
# 13317        Built-up  Area        Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area  2025-06-18 00:00:00           Padmanabhanagar
# 13319  Super built-up  Area        Ready To Move              Doddathoguru
#
#             size  society total_sqft bath balcony  price
# ...

# %%
df
# Out:
#                   area_type         availability                  location  \
# 0      Super built-up  Area  2025-12-19 00:00:00  Electronic City Phase II
# 1                Plot  Area        Ready To Move          Chikka Tirupathi
# 2            Built-up  Area        Ready To Move               Uttarahalli
# 3      Super built-up  Area        Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area        Ready To Move                  Kothanur
# ...                     ...                  ...                       ...
# 13315        Built-up  Area        Ready To Move                Whitefield
# 13316  Super built-up  Area        Ready To Move             Richards Town
# 13317        Built-up  Area        Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area  2025-06-18 00:00:00           Padmanabhanagar
# 13319  Super built-up  Area        Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# ...

# %%
# Filling different value in different column
df7 = df.fillna({'society':'abcd','balcony':'defg'})

# %%
df7
# Out:
#                   area_type         availability                  location  \
# 0      Super built-up  Area  2025-12-19 00:00:00  Electronic City Phase II
# 1                Plot  Area        Ready To Move          Chikka Tirupathi
# 2            Built-up  Area        Ready To Move               Uttarahalli
# 3      Super built-up  Area        Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area        Ready To Move                  Kothanur
# ...                     ...                  ...                       ...
# 13315        Built-up  Area        Ready To Move                Whitefield
# 13316  Super built-up  Area        Ready To Move             Richards Town
# 13317        Built-up  Area        Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area  2025-06-18 00:00:00           Padmanabhanagar
# 13319  Super built-up  Area        Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath balcony   price
# ...

# %%
# Filling the values by the mean of columns
df8 = df.fillna(int(df['balcony'].mean()))

# %%
df8
# Out:
#                   area_type         availability                  location  \
# 0      Super built-up  Area  2025-12-19 00:00:00  Electronic City Phase II
# 1                Plot  Area        Ready To Move          Chikka Tirupathi
# 2            Built-up  Area        Ready To Move               Uttarahalli
# 3      Super built-up  Area        Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area        Ready To Move                  Kothanur
# ...                     ...                  ...                       ...
# 13315        Built-up  Area        Ready To Move                Whitefield
# 13316  Super built-up  Area        Ready To Move             Richards Town
# 13317        Built-up  Area        Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area  2025-06-18 00:00:00           Padmanabhanagar
# 13319  Super built-up  Area        Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# ...

# %%
int(df['balcony'].mean())
# Out:
# 1

# %%
df9 = df.fillna(df['balcony'].max())

# %%
df9
# Out:
#                   area_type         availability                  location  \
# 0      Super built-up  Area  2025-12-19 00:00:00  Electronic City Phase II
# 1                Plot  Area        Ready To Move          Chikka Tirupathi
# 2            Built-up  Area        Ready To Move               Uttarahalli
# 3      Super built-up  Area        Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area        Ready To Move                  Kothanur
# ...                     ...                  ...                       ...
# 13315        Built-up  Area        Ready To Move                Whitefield
# 13316  Super built-up  Area        Ready To Move             Richards Town
# 13317        Built-up  Area        Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area  2025-06-18 00:00:00           Padmanabhanagar
# 13319  Super built-up  Area        Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# ...

# %%
df10 = df.fillna(df['balcony'].min())

# %%
df10
# Out:
#                   area_type         availability                  location  \
# 0      Super built-up  Area  2025-12-19 00:00:00  Electronic City Phase II
# 1                Plot  Area        Ready To Move          Chikka Tirupathi
# 2            Built-up  Area        Ready To Move               Uttarahalli
# 3      Super built-up  Area        Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area        Ready To Move                  Kothanur
# ...                     ...                  ...                       ...
# 13315        Built-up  Area        Ready To Move                Whitefield
# 13316  Super built-up  Area        Ready To Move             Richards Town
# 13317        Built-up  Area        Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area  2025-06-18 00:00:00           Padmanabhanagar
# 13319  Super built-up  Area        Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# ...

# %%
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df11 = df.dropna()

# %%
df11
# Out:
#                   area_type         availability                  location  \
# 0      Super built-up  Area  2025-12-19 00:00:00  Electronic City Phase II
# 1                Plot  Area        Ready To Move          Chikka Tirupathi
# 3      Super built-up  Area        Ready To Move        Lingadheeranahalli
# 5      Super built-up  Area        Ready To Move                Whitefield
# 11               Plot  Area        Ready To Move                Whitefield
# ...                     ...                  ...                       ...
# 13313  Super built-up  Area        Ready To Move               Uttarahalli
# 13314  Super built-up  Area        Ready To Move         Green Glen Layout
# 13315        Built-up  Area        Ready To Move                Whitefield
# 13317        Built-up  Area        Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area  2025-06-18 00:00:00           Padmanabhanagar
#
#             size  society total_sqft  bath  balcony   price
# ...

# %%
df11.reset_index()
# Out:
#       index             area_type         availability  \
# 0         0  Super built-up  Area  2025-12-19 00:00:00
# 1         1            Plot  Area        Ready To Move
# 2         3  Super built-up  Area        Ready To Move
# 3         5  Super built-up  Area        Ready To Move
# 4        11            Plot  Area        Ready To Move
# ...     ...                   ...                  ...
# 7491  13313  Super built-up  Area        Ready To Move
# 7492  13314  Super built-up  Area        Ready To Move
# 7493  13315        Built-up  Area        Ready To Move
# 7494  13317        Built-up  Area        Ready To Move
# 7495  13318  Super built-up  Area  2025-06-18 00:00:00
#
#                       location       size  society total_sqft  bath  balcony  \
# 0     Electronic City Phase II      2 BHK  Coomee        1056   2.0      1.0
# 1             Chikka Tirupathi  4 Bedroom  Theanmp       2600   5.0      3.0
# ...

# %%
df12 = df.dropna(how='all')

# %%
df12.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# society         0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %%
df13 = df.dropna(how='any')

# %%
df13
# Out:
#                   area_type         availability                  location  \
# 0      Super built-up  Area  2025-12-19 00:00:00  Electronic City Phase II
# 1                Plot  Area        Ready To Move          Chikka Tirupathi
# 3      Super built-up  Area        Ready To Move        Lingadheeranahalli
# 5      Super built-up  Area        Ready To Move                Whitefield
# 11               Plot  Area        Ready To Move                Whitefield
# ...                     ...                  ...                       ...
# 13313  Super built-up  Area        Ready To Move               Uttarahalli
# 13314  Super built-up  Area        Ready To Move         Green Glen Layout
# 13315        Built-up  Area        Ready To Move                Whitefield
# 13317        Built-up  Area        Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area  2025-06-18 00:00:00           Padmanabhanagar
#
#             size  society total_sqft  bath  balcony   price
# ...
